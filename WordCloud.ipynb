# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavanajamalpur/Basics_git/blob/main/WordCloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib wordcloud
import matplotlib.pyplot as plt

# %%
from wordcloud import WordCloud
text_data = "Bhavana Jamalpur . Word clouds are a fun way to visualize text!"

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)

# %%
plt.figure(figsize=(10, 5))

# %%
plt.imshow(wordcloud, interpolation='bilinear')
